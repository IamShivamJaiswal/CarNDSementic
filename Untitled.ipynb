# %%
# !pip install tensorflow tqdm
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (1.9.0)
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/7d/e6/19dfaff08fcbee7f3453e5b537e65a8364f1945f921a36d08be1e2ff3475/tqdm-4.24.0-py2.py3-none-any.whl (43kB)
#     100% |████████████████████████████████| 51kB 2.4MB/s
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.14.5)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: setuptools<=39.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (39.1.0)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorboard<1.10.0,>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.9.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.31.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.10.0,>=1.9.0->tensorflow) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.10.0,>=1.9.0->tensorflow) (2.6.11)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.24.0

# %%
import os.path
import sys
sys.path.insert(0, './drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/')
import tensorflow as tf
import helper
import warnings
#from distutils.verion import LooseVersion
import project_tests as tests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-620bf8bd45d3> in <module>()
#       3 sys.path.insert(0, './drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/')
#       4 import tensorflow as tf
# ----> 5 import helper
#       6 import warnings
#       7 #from distutils.verion import LooseVersion
#
# ModuleNotFoundError: No module named 'helper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !cd drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/helper.py
# Out:
# datalab  drive

# %%
import helper

# %%
def load_vgg(sess, vgg_path):
    """
    Load Pretrained VGG Model into TensorFlow.
    :param sess: TensorFlow Session
    :param vgg_path: Path to vgg folder, containing "variables/" and "saved_model.pb"
    :return: Tuple of Tensors from VGG model (image_input, keep_prob, layer3_out, layer4_out, layer7_out)
    """
    # TODO: Implement function
    #   Use tf.saved_model.loader.load to load the model and weights
    vgg_tag = 'vgg16'
    vgg_input_tensor_name = 'image_input:0'
    vgg_keep_prob_tensor_name = 'keep_prob:0'
    vgg_layer3_out_tensor_name = 'layer3_out:0'
    vgg_layer4_out_tensor_name = 'layer4_out:0'
    vgg_layer7_out_tensor_name = 'layer7_out:0'

    tf.saved_model.loader.load(sess, [vgg_tag], vgg_path)
    image_input = tf.get_default_graph().get_tensor_by_name(vgg_input_tensor_name)
    keep_prob = tf.get_default_graph().get_tensor_by_name(vgg_keep_prob_tensor_name)
    layer3_out = tf.get_default_graph().get_tensor_by_name(vgg_layer3_out_tensor_name)
    layer4_out = tf.get_default_graph().get_tensor_by_name(vgg_layer4_out_tensor_name)
    layer7_out = tf.get_default_graph().get_tensor_by_name(vgg_layer7_out_tensor_name)
    
    return image_input, keep_prob, layer3_out, layer4_out, layer7_out
tests.test_load_vgg(load_vgg, tf)


def layers(vgg_layer3_out, vgg_layer4_out, vgg_layer7_out, num_classes):
    """
    Create the layers for a fully convolutional network.  Build skip-layers using the vgg layers.
    :param vgg_layer7_out: TF Tensor for VGG Layer 3 output
    :param vgg_layer4_out: TF Tensor for VGG Layer 4 output
    :param vgg_layer3_out: TF Tensor for VGG Layer 7 output
    :param num_classes: Number of classes to classify
    :return: The Tensor for the last layer of output
    """
    # TODO: Implement function
    # 1x1 convolution of vgg layer 7
    layer7a_out = tf.layers.conv2d(vgg_layer7_out, num_classes, 1, 
                                   padding= 'same', 
                                   kernel_initializer= tf.random_normal_initializer(stddev=0.01),
                                   kernel_regularizer= tf.contrib.layers.l2_regularizer(1e-3))
    # upsample
    layer4a_in1 = tf.layers.conv2d_transpose(layer7a_out, num_classes, 4, 
                                             strides= (2, 2), 
                                             padding= 'same', 
                                             kernel_initializer= tf.random_normal_initializer(stddev=0.01), 
                                             kernel_regularizer= tf.contrib.layers.l2_regularizer(1e-3))
    # make sure the shapes are the same!
    # 1x1 convolution of vgg layer 4
    layer4a_in2 = tf.layers.conv2d(vgg_layer4_out, num_classes, 1, 
                                   padding= 'same', 
                                   kernel_initializer= tf.random_normal_initializer(stddev=0.01), 
                                   kernel_regularizer= tf.contrib.layers.l2_regularizer(1e-3))
    # skip connection (element-wise addition)
    layer4a_out = tf.add(layer4a_in1, layer4a_in2)
    # upsample
    layer3a_in1 = tf.layers.conv2d_transpose(layer4a_out, num_classes, 4,  
                                             strides= (2, 2), 
                                             padding= 'same', 
                                             kernel_initializer= tf.random_normal_initializer(stddev=0.01), 
                                             kernel_regularizer= tf.contrib.layers.l2_regularizer(1e-3))
    # 1x1 convolution of vgg layer 3
    layer3a_in2 = tf.layers.conv2d(vgg_layer3_out, num_classes, 1, 
                                   padding= 'same', 
                                   kernel_initializer= tf.random_normal_initializer(stddev=0.01), 
                                   kernel_regularizer= tf.contrib.layers.l2_regularizer(1e-3))
    # skip connection (element-wise addition)
    layer3a_out = tf.add(layer3a_in1, layer3a_in2)
    # upsample
    nn_last_layer = tf.layers.conv2d_transpose(layer3a_out, num_classes, 16,  
                                               strides= (8, 8), 
                                               padding= 'same', 
                                               kernel_initializer= tf.random_normal_initializer(stddev=0.01), 
                                               kernel_regularizer= tf.contrib.layers.l2_regularizer(1e-3))
    return nn_last_layer
tests.test_layers(layers)


def optimize(nn_last_layer, correct_label, learning_rate, num_classes):
    """
    Build the TensorFLow loss and optimizer operations.
    :param nn_last_layer: TF Tensor of the last layer in the neural network
    :param correct_label: TF Placeholder for the correct label image
    :param learning_rate: TF Placeholder for the learning rate
    :param num_classes: Number of classes to classify
    :return: Tuple of (logits, train_op, cross_entropy_loss)
    """
    # TODO: Implement function
    # make logits a 2D tensor where each row represents a pixel and each column a class
    logits = tf.reshape(nn_last_layer, (-1, num_classes))
    correct_label = tf.reshape(correct_label, (-1,num_classes))
    # define loss function
    cross_entropy_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits= logits, labels= correct_label))
    # define training operation
    optimizer = tf.train.AdamOptimizer(learning_rate= learning_rate)
    train_op = optimizer.minimize(cross_entropy_loss)

    return logits, train_op, cross_entropy_loss
tests.test_optimize(optimize)


def train_nn(sess, epochs, batch_size, get_batches_fn, train_op, cross_entropy_loss, input_image,
             correct_label, keep_prob, learning_rate):
    """
    Train neural network and print out the loss during training.
    :param sess: TF Session
    :param epochs: Number of epochs
    :param batch_size: Batch size
    :param get_batches_fn: Function to get batches of training data.  Call using get_batches_fn(batch_size)
    :param train_op: TF Operation to train the neural network
    :param cross_entropy_loss: TF Tensor for the amount of loss
    :param input_image: TF Placeholder for input images
    :param correct_label: TF Placeholder for label images
    :param keep_prob: TF Placeholder for dropout keep probability
    :param learning_rate: TF Placeholder for learning rate
    """
    # TODO: Implement function
    sess.run(tf.global_variables_initializer())
    
    print("Training...")
    print()
    for i in range(epochs):
        print("EPOCH {} ...".format(i+1))
        for image, label in get_batches_fn(batch_size):
            _, loss = sess.run([train_op, cross_entropy_loss], 
                               feed_dict={input_image: image, correct_label: label,                                keep_prob: 0.5, learning_rate: 0.0009})
            print("Loss: = {:.3f}".format(loss))
        print()
tests.test_train_nn(train_nn)

# %%
def run():
    num_classes = 2
    image_shape = (160, 576)
    data_dir = './drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road'
    runs_dir = './drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/runs'
    #tests.test_for_kitti_dataset(data_dir)

    # Download pretrained vgg model
    helper.maybe_download_pretrained_vgg(data_dir)

    # OPTIONAL: Train and Inference on the cityscapes dataset instead of the Kitti dataset.
    # You'll need a GPU with at least 10 teraFLOPS to train on.
    #  https://www.cityscapes-dataset.com/

    with tf.Session() as sess:
        # Path to vgg model
        vgg_path = os.path.join(data_dir, 'vgg')
        # Create function to get batches
        get_batches_fn = helper.gen_batch_function(os.path.join(data_dir, 'data_road/training'), image_shape)

        # OPTIONAL: Augment Images for better results
        #  https://datascience.stackexchange.com/questions/5224/how-to-prepare-augment-images-for-neural-network

        # TODO: Build NN using load_vgg, layers, and optimize function

        epochs = 2
        batch_size = 5

        # TF placeholders
        correct_label = tf.placeholder(tf.int32, [None, None, None, num_classes], name='correct_label')
        learning_rate = tf.placeholder(tf.float32, name='learning_rate')

        input_image, keep_prob, vgg_layer3_out, vgg_layer4_out, vgg_layer7_out = load_vgg(sess, vgg_path)

        nn_last_layer = layers(vgg_layer3_out, vgg_layer4_out, vgg_layer7_out, num_classes)

        logits, train_op, cross_entropy_loss = optimize(nn_last_layer, correct_label, learning_rate, num_classes)

        # TODO: Train NN using the train_nn function

        train_nn(sess, epochs, batch_size, get_batches_fn, train_op, cross_entropy_loss, input_image,
             correct_label, keep_prob, learning_rate)

        # TODO: Save inference data using helper.save_inference_samples
        helper.save_inference_samples(runs_dir, data_dir, sess, image_shape, logits, keep_prob, input_image)

        # OPTIONAL: Apply the trained model to a video

# %%
if __name__ == '__main__':
    run()

# %%
##Command to unzip to detination 
# !unzip ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/vgg/vgg.zip -d ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/

# %%
# !ls
# Out:
# CarND-Semantic-Segmentation-master  datalab  data_road	drive  vgg

# %%
data_dir = './drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/vgg.zip'
vgg_filename = 'vgg.zip'
vgg_path = os.path.join(data_dir, 'vgg')
zip_ref = zipfile.ZipFile(os.path.join(vgg_path, vgg_filename), 'r')
zip_ref.extractall(data_dir)
zip_ref.close()

# %%
# !python ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/main.py
# Out:
# 2018-08-10 16:57:54.133135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-08-10 16:57:54.133649: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-08-10 16:57:54.133698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-10 16:57:54.486991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-10 16:57:54.487053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-10 16:57:54.487077: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-10 16:57:54.487382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/device:GPU:0 with 10763 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# 2018-08-10 16:57:54.712823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-10 16:57:54.712908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-10 16:57:54.712942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-10 16:57:54.712970: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-10 16:57:54.713120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/device:GPU:0 with 10763 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Default GPU Device: /device:GPU:0
# 2018-08-10 16:57:54.724134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-10 16:57:54.724191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-10 16:57:54.724216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-10 16:57:54.724252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-10 16:57:54.724388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10763 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Tests Passed
# Tests Passed
# WARNING:tensorflow:From ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/main.py:115: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# 2018-08-10 16:57:58.758941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-10 16:57:58.759028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-10 16:57:58.759054: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-10 16:57:58.759082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-10 16:57:58.759239: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10763 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Tests Passed
# 2018-08-10 16:57:58.802835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-10 16:57:58.802891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-10 16:57:58.802916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-10 16:57:58.802945: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-10 16:57:58.803077: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10763 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Tests Passed
# 2018-08-10 16:57:59.711425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-08-10 16:57:59.711565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-08-10 16:57:59.711596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-08-10 16:57:59.711618: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# 2018-08-10 16:57:59.711871: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1084] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10763 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# 2018-08-10 16:58:16.702418: W tensorflow/core/graph/graph_constructor.cc:1248] Importing a graph with a lower producer version 21 into an existing graph with producer version 26. Shape inference will have run different parts of the graph with different producer versions.
# Training...
#
# EPOCH 1 ...
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00136.jpg
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00139.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00095.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00044.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00027.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00065.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00061.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00078.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00037.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00023.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00077.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00141.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00109.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00046.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00021.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00092.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00111.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00081.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00128.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00033.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00080.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00106.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00068.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00022.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00093.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00084.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00073.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00051.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00129.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00049.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00056.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00135.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00108.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00103.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00137.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00145.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00069.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00053.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00024.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00026.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00028.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00086.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00133.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00043.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00089.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00125.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00142.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00094.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00076.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00144.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00087.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00143.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00114.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00090.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00032.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00146.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00071.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00118.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00040.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00075.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00149.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00140.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00018.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00110.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00017.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00099.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00100.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00101.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00074.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00035.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00096.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00131.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00038.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00034.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00148.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00019.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00041.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00134.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00052.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00116.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00054.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00147.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00020.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00058.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00102.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00126.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00112.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00132.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00057.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00050.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00091.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00115.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00064.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00122.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00117.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00047.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00088.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00098.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00016.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00107.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00120.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00121.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00059.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00031.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00127.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00113.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00105.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00070.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00030.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00082.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00063.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00025.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00123.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00036.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00097.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00072.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00066.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00048.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00055.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00083.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00119.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00085.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00079.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00104.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00029.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00067.jpg
# Loss: = 0.0000
#
# EPOCH 2 ...
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00065.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00105.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00033.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00127.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00057.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00049.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00104.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00026.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00111.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00096.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00067.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00118.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00076.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00146.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00080.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00102.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00073.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00099.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00109.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00043.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00017.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00019.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00046.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00133.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00036.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00122.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00144.jpg
# ./drive/TrackSementic/CarND-Semantic-Segmentation-master/CarND-Semantic-Segmentation-master/data_road/track_00018.jpg
# ^C

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/7d/e6/19dfaff08fcbee7f3453e5b537e65a8364f1945f921a36d08be1e2ff3475/tqdm-4.24.0-py2.py3-none-any.whl (43kB)
#     100% |████████████████████████████████| 51kB 3.6MB/s
# Installing collected packages: tqdm
# Successfully installed tqdm-4.24.0

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/45/99/837428d26b47ebd6b66d6e1b180e98ec4a557767a93a81a02ea9d6242611/GPUtil-1.3.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gputil) (1.14.5)
# Building wheels for collected packages: gputil
# done
#   Stored in directory: /content/.cache/pip/wheels/17/0f/04/b79c006972335e35472c0b835ed52bfc0815258d409f560108
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.3.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.6)
# Collecting humanize
#   Downloading https://files.pythonhosted.org/packages/8c/e0/e512e4ac6d091fc990bbe13f9e0378f34cf6eecd1c6c268c9e598dcf5bb9/humanize-0.5.1.tar.gz
# Building wheels for collected packages: humanize
# done
#   Stored in directory: /content/.cache/pip/wheels/69/86/6c/f8b8593bc273ec4b0c653d3827f7482bb2001a2781a73b7f44
# Successfully built humanize
# Installing collected packages: humanize
# Successfully installed humanize-0.5.1

# %%
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Gen RAM Free: 12.6 GB  | Proc size: 264.6 MB
# GPU RAM Free: 11439MB | Used: 0MB | Util   0% | Total 11439MB

# %%
# !kill -9 -1

# %%
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !mkdir -p drive
# !google-drive-ocamlfuse drive
print('Files in Drive:')
#ls drive/
# Out:
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.
# Files in Drive:
